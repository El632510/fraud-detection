# %% [markdown]
# # Feature Engineering
# ### Feature engineering steps (time_since_signup, hour_of_day,
# ### day_of_week, user_transaction_count, IP-to-country mapping)
# ### are documented in eda-fraud-data.ipynb Task 1 notebook.
# ### 10 Academy KAIM9 | Eleni Melkie
